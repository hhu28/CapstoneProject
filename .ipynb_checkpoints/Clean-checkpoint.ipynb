# %%
import pandas as pd
import numpy as np

# %%
# read in the data
origin = pd.read_csv("originaldata.csv", low_memory=False)

# %%
list(origin)
# Out:
# ['RA_Report #',
#  'RA_CAERS Created Date',
#  'AEC_Event Start Date',
#  'PRI_Product Role',
#  'PRI_Reported Brand/Product Name',
#  'PRI_FDA Industry Code',
#  'PRI_FDA Industry Name',
#  'CI_Age at Adverse Event',
#  'CI_Age Unit',
#  'CI_Gender',
#  'AEC_One Row Outcomes',
#  'SYM_One Row Coded Symptoms']

# %%
origin
# Out:
#        RA_Report # RA_CAERS Created Date AEC_Event Start Date  \
# 0            65325                1/1/04               8/4/03
# 1            65333                1/1/04                  NaN
# 2            65335                1/1/04             11/24/03
# 3            65336                1/1/04                  NaN
# 4            65345                1/1/04             12/21/03
# 5            65350                1/1/04                  NaN
# 6            65353                1/2/04              12/1/03
# 7            65353                1/2/04              12/1/03
# 8            65354                1/2/04                  NaN
# 9            65355                1/2/04             10/27/03
# 10           65356                1/2/04             10/27/03
# 11           65357                1/2/04             10/27/03
# 12           65379                1/3/04              11/5/03
# 13           65387                1/3/04                  NaN
# 14           65388                1/3/04             12/30/03
# 15           65399                1/5/04             11/22/03
# 16           65400                1/5/04               9/5/01
# 17           65403                1/5/04               3/4/03
# 18           65404                1/5/04                  NaN
# 19           65416                1/6/04             11/15/03
# 20           65419                1/6/04                  NaN
# 21           65420                1/6/04              11/1/03
# 22           65420                1/6/04              11/1/03
# 23           65420                1/6/04              11/1/03
# 24           65420                1/6/04              11/1/03
# 25           65420                1/6/04              11/1/03
# 26           65420                1/6/04              11/1/03
# 27           65420                1/6/04              11/1/03
# 28           65420                1/6/04              11/1/03
# 29           65420                1/6/04              11/1/03
# ...            ...                   ...                  ...
# 80139       205260              12/15/16             10/23/16
# 80140       205300              12/16/16             10/15/16
# 80141       205312              12/16/16                  NaN
# 80142       205323              12/16/16             12/14/16
# 80143       205325              12/16/16              12/8/16
# 80144       205351              12/19/16              12/2/16
# 80145       205397              12/20/16             11/23/16
# 80146       205473              12/21/16             12/13/16
# 80147       205481              12/21/16             12/19/16
# 80148       205483              12/21/16                  NaN
# 80149       205483              12/21/16                  NaN
# 80150       205483              12/21/16                  NaN
# 80151       205484              12/21/16                  NaN
# 80152       205575              12/22/16             12/20/16
# 80153       205616              12/23/16             12/22/16
# 80154       205668              12/27/16              6/14/16
# 80155       205669              12/27/16                  NaN
# 80156       205670              12/27/16                  NaN
# 80157       205670              12/27/16                  NaN
# 80158       205671              12/27/16                  NaN
# 80159       205673              12/27/16              10/7/16
# 80160       205680              12/27/16             12/23/16
# 80161       205691              12/27/16             12/15/16
# 80162       205711              12/28/16              4/28/16
# 80163       205723              12/28/16                  NaN
# 80164       205724              12/28/16             12/17/16
# 80165       205753              12/28/16                  NaN
# 80166       205814              12/29/16             12/25/16
# 80167       205817              12/29/16             12/27/10
# 80168       205865              12/30/16               8/1/16
#
#       PRI_Product Role                    PRI_Reported Brand/Product Name  \
# 0              Suspect      MIDWEST COUNTRY FAIR CHOCOLATE FLAVORED CHIPS
# 1              Suspect  KROGER CLASSIC CREAM-DE-MINT CANDY MINT CHIP I...
# 2              Suspect                         ENFAMIL LIPIL BABY FORMULA
# 3              Suspect                         ENFIMIL LIPIL BABY FORMULA
# 4              Suspect        FRITO LAY FUNYUNS ONION FLAVOR, ONION RINGS
# 5              Suspect                                              GRAPE
# 6              Suspect                                HERBALIFE RELAX NOW
# 7              Suspect                            HERBALIFE TOTAL CONTROL
# 8              Suspect                                            YOHIMBE
# 9              Suspect         CAL-C PEACH TROPIC ENRICHED BEVERAGE BLEND
# 10             Suspect         CAL-C PEACH TROPIC ENRICHED BEVERAGE BLEND
# 11             Suspect         CAL-C PEACH TROPIC ENRICHED BEVERAGE BLEND
# 12             Suspect                 I CONTACT LIP-INK (SEMI-PERMANENT)
# 13             Suspect                            H.P. HOOD HALF AND HALF
# 14             Suspect   LACTAID REDUCED FAT (2%) MILK; 100% LACTOSE FREE
# 15             Suspect                                     METOBOLITE 356
# 16             Suspect                                         METABOLIFE
# 17             Suspect                              METABOLIFE METABOLIFE
# 18             Suspect                     ENIVA MINERALS FOR LIFE-SILVER
# 19             Suspect                                            AVLIMIL
# 20             Suspect                                            AVLIMIL
# 21             Suspect                                             COFFEE
# 22             Suspect                            DIET CAFFEINE FREE COKE
# 23             Suspect                                          DIET COKE
# 24             Suspect                                         DIET PEPSI
# 25             Suspect                                        DIET SPRITE
# 26             Suspect                                               JAMS
# 27             Suspect                                   LISTERINE STRIPS
# 28             Suspect                                         NUTRASWEET
# 29             Suspect                                           PUDDINGS
# ...                ...                                                ...
# 80139          Suspect                   BLUE BUNNY ICE CREAM BUNNY TRACK
# 80140          Suspect              BLUE BELL COOKIES AND CREAM ICE CREAM
# 80141          Suspect                                   NESTLE PUSH POPS
# 80142          Suspect               BRI ALPHA LIPOIC ACID EXTRA STRENGTH
# 80143          Suspect  PURIFIED BRAND OMNI CLEANSING DRINK EXTRA STRE...
# 80144          Suspect                                            PAMONHA
# 80145          Suspect                  LIPO-FLAVONOID PLUS (NONSPECIFIC)
# 80146          Suspect                          CHOCOLATE CUSTARD DELIGHT
# 80147          Suspect  LARA CASHEW AND ALMOND BUTTER NUT SPREAD WITH ...
# 80148          Suspect                   WEN ANTI-FRIZZ SWEET ALMOND MINT
# 80149          Suspect                       WEN MOUSSE SWEET ALMOND MINT
# 80150          Suspect        WEN SWEET ALMOND MINT CLEANSING CONDITIONER
# 80151          Suspect                CALTRATE (CALCIUM CARBONATE) TABLET
# 80152          Suspect                                       Q&B KILLISHI
# 80153          Suspect                                   IT WORKS CLEANSE
# 80154          Suspect                    MINUTE MAID PREMIUM GRAPE PUNCH
# 80155          Suspect        WEN SWEET ALMOND MINT CLEANSING CONDITIONER
# 80156          Suspect                WEN CLEANSING CONDITIONER (UNKNOWN)
# 80157          Suspect        WEN SWEET ALMOND MINT CLEANSING CONDITIONER
# 80158          Suspect                       DAIRY STAR NON-DAIRY CREAMER
# 80159          Suspect                 PUBLIX SOUTHERN STYLE POTATO SALAD
# 80160          Suspect                            BUSH'S BEST MAPLE CURED
# 80161          Suspect                                       ALOE LAX 450
# 80162          Suspect      TRY ME YUCATAN SUNSHINE HABANERO PEPPER SAUCE
# 80163          Suspect  EQUATE COMPLETE ADULTS 50+ MULTIVITAMIN/MULTI-...
# 80164          Suspect                                ENFAMIL NEUTRAMIGEN
# 80165          Suspect                      WEN CLEANSING CONDITIONER KIT
# 80166          Suspect                              DARK CRUNCH CHOCOLATE
# 80167          Suspect                                  ST IVES FACE WASH
# 80168          Suspect                           WEN CONDITIONING SHAMPOO
#
#       PRI_FDA Industry Code                   PRI_FDA Industry Name  \
# 0                         3             Bakery Prod/Dough/Mix/Icing
# 1                        13                          Ice Cream Prod
# 2                        40                          Baby Food Prod
# 3                        40                          Baby Food Prod
# 4                         7                         Snack Food Item
# 5                        20                        Fruit/Fruit Prod
# 6                        54  Vit/Min/Prot/Unconv Diet(Human/Animal)
# 7                        54  Vit/Min/Prot/Unconv Diet(Human/Animal)
# 8                        54  Vit/Min/Prot/Unconv Diet(Human/Animal)
# 9                        29                        Soft Drink/Water
# 10                       29                        Soft Drink/Water
# 11                       29                        Soft Drink/Water
# 12                       53                               Cosmetics
# 13                        9             Milk/Butter/Dried Milk Prod
# 14                        9             Milk/Butter/Dried Milk Prod
# 15                       54  Vit/Min/Prot/Unconv Diet(Human/Animal)
# 16                       54  Vit/Min/Prot/Unconv Diet(Human/Animal)
# 17                       54  Vit/Min/Prot/Unconv Diet(Human/Animal)
# 18                       54  Vit/Min/Prot/Unconv Diet(Human/Animal)
# 19                       54  Vit/Min/Prot/Unconv Diet(Human/Animal)
# 20                       54  Vit/Min/Prot/Unconv Diet(Human/Animal)
# 21                       31                              Coffee/Tea
# 22                       29                        Soft Drink/Water
# 23                       29                        Soft Drink/Water
# 24                       29                        Soft Drink/Water
# 25                       29                        Soft Drink/Water
# 26                       22                        Fruit/Fruit Prod
# 27                       53                               Cosmetics
# 28                       45              Food Additives (Human Use)
# 29                       35  Gelatin/Rennet/Pudding Mix/Pie Filling
# ...                     ...                                     ...
# 80139                    13                          Ice Cream Prod
# 80140                    13                          Ice Cream Prod
# 80141                    13                          Ice Cream Prod
# 80142                    54  Vit/Min/Prot/Unconv Diet(Human/Animal)
# 80143                    54  Vit/Min/Prot/Unconv Diet(Human/Animal)
# 80144                     2    Whole Grain/Milled Grain Prod/Starch
# 80145                    54  Vit/Min/Prot/Unconv Diet(Human/Animal)
# 80146                    13                          Ice Cream Prod
# 80147                    23                        Nuts/Edible Seed
# 80148                    53                               Cosmetics
# 80149                    53                               Cosmetics
# 80150                    53                               Cosmetics
# 80151                    54  Vit/Min/Prot/Unconv Diet(Human/Animal)
# 80152                    17         Meat, Meat Products and Poultry
# 80153                    54  Vit/Min/Prot/Unconv Diet(Human/Animal)
# 80154                    29                        Soft Drink/Water
# 80155                    53                               Cosmetics
# 80156                    53                               Cosmetics
# 80157                    53                               Cosmetics
# 80158                    14              Filled Milk/Imit Milk Prod
# 80159                    39                         Prep Salad Prod
# 80160                    24           Vegetables/Vegetable Products
# 80161                    54  Vit/Min/Prot/Unconv Diet(Human/Animal)
# 80162                    27                      Dressing/Condiment
# 80163                    54  Vit/Min/Prot/Unconv Diet(Human/Animal)
# 80164                    40                          Baby Food Prod
# 80165                    53                               Cosmetics
# 80166                    34                         Choc/Cocoa Prod
# 80167                    53                               Cosmetics
# 80168                    53                               Cosmetics
#
#        CI_Age at Adverse Event    CI_Age Unit      CI_Gender  \
# 0                          2.0        Year(s)         Female
# 1                          NaN  Not Available         Female
# 2                          3.0       Month(s)  Not Available
# 3                          NaN  Not Available  Not Available
# 4                         10.0        Year(s)           Male
# 5                          NaN  Not Available  Not Available
# 6                          NaN  Not Available         Female
# 7                          NaN  Not Available         Female
# 8                         66.0        Year(s)           Male
# 9                          NaN  Not Available           Male
# 10                         NaN  Not Available  Not Available
# 11                         NaN  Not Available  Not Available
# 12                         NaN  Not Available         Female
# 13                         NaN  Not Available         Female
# 14                         NaN  Not Available           Male
# 15                        51.0        Year(s)           Male
# 16                        45.0        Year(s)         Female
# 17                        54.0        Year(s)         Female
# 18                        16.0        Year(s)           Male
# 19                        36.0        Year(s)         Female
# 20                        48.0        Year(s)         Female
# 21                        33.0        Year(s)           Male
# 22                        33.0        Year(s)           Male
# 23                        33.0        Year(s)           Male
# 24                        33.0        Year(s)           Male
# 25                        33.0        Year(s)           Male
# 26                        33.0        Year(s)           Male
# 27                        33.0        Year(s)           Male
# 28                        33.0        Year(s)           Male
# 29                        33.0        Year(s)           Male
# ...                        ...            ...            ...
# 80139                      NaN  Not Available  Not Available
# 80140                      NaN  Not Available           Male
# 80141                      NaN  Not Available         Female
# 80142                     60.0        Year(s)         Female
# 80143                     34.0        Year(s)           Male
# 80144                      NaN  Not Available         Female
# 80145                     75.0        Year(s)         Female
# 80146                     31.0        Year(s)           Male
# 80147                      NaN  Not Available         Female
# 80148                      NaN  Not Available         Female
# 80149                      NaN  Not Available         Female
# 80150                      NaN  Not Available         Female
# 80151                     59.0        Year(s)           Male
# 80152                     28.0        Year(s)           Male
# 80153                     23.0        Year(s)         Female
# 80154                      NaN  Not Available  Not Available
# 80155                      NaN  Not Available         Female
# 80156                      NaN  Not Available         Female
# 80157                      NaN  Not Available         Female
# 80158                      NaN  Not Available  Not Available
# 80159                      5.0        Year(s)  Not Available
# 80160                     53.0        Year(s)         Female
# 80161                      NaN  Not Available         Female
# 80162                      NaN  Not Available         Female
# 80163                      NaN  Not Available         Female
# 80164                      NaN  Not Available         Female
# 80165                      NaN  Not Available         Female
# 80166                      NaN  Not Available           Male
# 80167                     27.0        Year(s)         Female
# 80168                      NaN  Not Available           Male
#
#                                     AEC_One Row Outcomes  \
# 0      VISITED AN ER, VISITED A HEALTH CARE PROVIDER,...
# 1                                          VISITED AN ER
# 2                          NON-SERIOUS INJURIES/ ILLNESS
# 3                         VISITED A HEALTH CARE PROVIDER
# 4                          NON-SERIOUS INJURIES/ ILLNESS
# 5                                                  DEATH
# 6                         VISITED A HEALTH CARE PROVIDER
# 7                         VISITED A HEALTH CARE PROVIDER
# 8              REQ. INTERVENTION TO PRVNT PERM. IMPRMNT.
# 9                          NON-SERIOUS INJURIES/ ILLNESS
# 10                         NON-SERIOUS INJURIES/ ILLNESS
# 11                         NON-SERIOUS INJURIES/ ILLNESS
# 12                         NON-SERIOUS INJURIES/ ILLNESS
# 13                         NON-SERIOUS INJURIES/ ILLNESS
# 14                         NON-SERIOUS INJURIES/ ILLNESS
# 15                                                 DEATH
# 16                                                 DEATH
# 17                     LIFE THREATENING, HOSPITALIZATION
# 18                        VISITED A HEALTH CARE PROVIDER
# 19                        VISITED A HEALTH CARE PROVIDER
# 20                         NON-SERIOUS INJURIES/ ILLNESS
# 21                          LIFE THREATENING, DISABILITY
# 22                          LIFE THREATENING, DISABILITY
# 23                          LIFE THREATENING, DISABILITY
# 24                          LIFE THREATENING, DISABILITY
# 25                          LIFE THREATENING, DISABILITY
# 26                          LIFE THREATENING, DISABILITY
# 27                          LIFE THREATENING, DISABILITY
# 28                          LIFE THREATENING, DISABILITY
# 29                          LIFE THREATENING, DISABILITY
# ...                                                  ...
# 80139                      NON-SERIOUS INJURIES/ ILLNESS
# 80140                      NON-SERIOUS INJURIES/ ILLNESS
# 80141                          SERIOUS INJURIES/ ILLNESS
# 80142           OTHER SERIOUS (IMPORTANT MEDICAL EVENTS)
# 80143           OTHER SERIOUS (IMPORTANT MEDICAL EVENTS)
# 80144           OTHER SERIOUS (IMPORTANT MEDICAL EVENTS)
# 80145  VISITED A HEALTH CARE PROVIDER, OTHER SERIOUS ...
# 80146                      NON-SERIOUS INJURIES/ ILLNESS
# 80147                                      VISITED AN ER
# 80148                     VISITED A HEALTH CARE PROVIDER
# 80149                     VISITED A HEALTH CARE PROVIDER
# 80150                     VISITED A HEALTH CARE PROVIDER
# 80151                                              DEATH
# 80152                     HOSPITALIZATION, VISITED AN ER
# 80153    VISITED A HEALTH CARE PROVIDER, HOSPITALIZATION
# 80154                      NON-SERIOUS INJURIES/ ILLNESS
# 80155                      NON-SERIOUS INJURIES/ ILLNESS
# 80156                      NON-SERIOUS INJURIES/ ILLNESS
# 80157                      NON-SERIOUS INJURIES/ ILLNESS
# 80158                      NON-SERIOUS INJURIES/ ILLNESS
# 80159                      NON-SERIOUS INJURIES/ ILLNESS
# 80160           OTHER SERIOUS (IMPORTANT MEDICAL EVENTS)
# 80161  DISABILITY, VISITED A HEALTH CARE PROVIDER, OT...
# 80162                      NON-SERIOUS INJURIES/ ILLNESS
# 80163                      NON-SERIOUS INJURIES/ ILLNESS
# 80164                                    HOSPITALIZATION
# 80165                      NON-SERIOUS INJURIES/ ILLNESS
# 80166                  LIFE THREATENING, HOSPITALIZATION
# 80167                     VISITED A HEALTH CARE PROVIDER
# 80168                      NON-SERIOUS INJURIES/ ILLNESS
#
#                               SYM_One Row Coded Symptoms
# 0      SWELLING FACE, WHEEZING, COUGH, RASH, HOSPITAL...
# 1                           NAUSEA, DYSGEUSIA, DIARRHOEA
# 2                    GASTROINTESTINAL DISORDER, VOMITING
# 3        GASTROINTESTINAL DISORDER, PHYSICAL EXAMINATION
# 4                                                CHOKING
# 5                                         DEATH, CHOKING
# 6               PARANOIA, PHYSICAL EXAMINATION, DELUSION
# 7               PARANOIA, PHYSICAL EXAMINATION, DELUSION
# 8                               BLOOD PRESSURE INCREASED
# 9      FLUSHING, MALAISE, RASH, ABDOMINAL PAIN, DIARR...
# 10     LOOSE STOOLS, ABDOMINAL PAIN UPPER, VOMITING, ...
# 11     RASH, LOOSE STOOLS, ABDOMINAL PAIN UPPER, MALA...
# 12                      SWELLING FACE, PARAESTHESIA ORAL
# 13                                           PHARYNGITIS
# 14                                              VOMITING
# 15             COMPLETED SUICIDE, STRESS SYMPTOMS, DEATH
# 16                      DEATH, MITRAL VALVE INCOMPETENCE
# 17                              CEREBROVASCULAR ACCIDENT
# 18           MUCOSAL DISCOLOURATION, SKIN DISCOLOURATION
# 19     HEART RATE INCREASED, DIZZINESS, BLOOD PRESSUR...
# 20                                     PAIN IN EXTREMITY
# 21     PARAESTHESIA, PHYSICAL EXAMINATION, HOSPITALIS...
# 22     PARAESTHESIA, PHYSICAL EXAMINATION, HOSPITALIS...
# 23     PARAESTHESIA, PHYSICAL EXAMINATION, HOSPITALIS...
# 24     PARAESTHESIA, PHYSICAL EXAMINATION, HOSPITALIS...
# 25     PARAESTHESIA, PHYSICAL EXAMINATION, HOSPITALIS...
# 26     PARAESTHESIA, PHYSICAL EXAMINATION, HOSPITALIS...
# 27     PARAESTHESIA, PHYSICAL EXAMINATION, HOSPITALIS...
# 28     PARAESTHESIA, PHYSICAL EXAMINATION, HOSPITALIS...
# 29     PARAESTHESIA, PHYSICAL EXAMINATION, HOSPITALIS...
# ...                                                  ...
# 80139            ABDOMINAL PAIN UPPER, DIARRHOEA, NAUSEA
# 80140  ABDOMINAL PAIN, DIARRHOEA, NAUSEA, HYPERHIDROS...
# 80141                                               RASH
# 80142  DIARRHOEA, MALAISE, ABDOMINAL PAIN UPPER, ABDO...
# 80143                     DIZZINESS, VOMITING, HOT FLUSH
# 80144                                 DIARRHOEA, MALAISE
# 80145  HYPERSENSITIVITY, PHARYNGEAL OEDEMA, DYSPHAGIA...
# 80146                                   HYPERSENSITIVITY
# 80147                                   HYPERSENSITIVITY
# 80148  ALOPECIA, SECRETION DISCHARGE, CHEMICAL BURN O...
# 80149  ALOPECIA, SECRETION DISCHARGE, CHEMICAL BURN O...
# 80150  ALOPECIA, SECRETION DISCHARGE, CHEMICAL BURN O...
# 80151                                              DEATH
# 80152                     HYPERSENSITIVITY, FOOD ALLERGY
# 80153            MALAISE, PANCREATITIS, LIPASE INCREASED
# 80154               ABDOMINAL PAIN, ABDOMINAL PAIN UPPER
# 80155                                           ALOPECIA
# 80156  ALOPECIA, SKIN SENSITISATION, ALOPECIA, PARAES...
# 80157  ALOPECIA, SKIN SENSITISATION, ALOPECIA, PARAES...
# 80158                 MALAISE, ABDOMINAL PAIN, DIARRHOEA
# 80159  ABDOMINAL PAIN, VOMITING, ABDOMINAL PAIN UPPER...
# 80160                                         LACERATION
# 80161  RENAL FAILURE ACUTE, RENAL INJURY, FATIGUE, TU...
# 80162                                             NAUSEA
# 80163                                 HEADACHE, TINNITUS
# 80164                                            MALAISE
# 80165                                           ALOPECIA
# 80166  DYSPNOEA, ANAPHYLACTIC REACTION, DYSPHAGIA, AB...
# 80167                           EYE PAIN, EYE IRRITATION
# 80168                 SKIN IRRITATION, BURNING SENSATION
#
# [80169 rows x 12 columns]

# %%
# define variables types:
origin['RA_Report #'] = origin['RA_Report #'].astype('str')  
#origin['RA_CAERS Created Date'] = origin['RA_CAERS Created Date'].astype('str') 
#origin['AEC_Event Start Date'] 
origin['PRI_Product Role'] = origin['PRI_Product Role'].astype('str') 
origin['PRI_Reported Brand/Product Name'] = origin['PRI_Reported Brand/Product Name'].astype('str')
origin['PRI_FDA Industry Code'] = origin['PRI_FDA Industry Code'].astype('str')           
origin['PRI_FDA Industry Name'] = origin['PRI_FDA Industry Name'].astype('str')
origin['CI_Age Unit'] = origin['CI_Age Unit'].astype('str')
origin['CI_Gender'] = origin['CI_Gender'].astype('str')
origin['SYM_One Row Coded Symptoms'] = origin['SYM_One Row Coded Symptoms'].astype('str')

# convert last column from strings to lists (time consuming!)
# for i in range(50):
#     #print i
#     origin['SYM_One Row Coded Symptoms'][i] = origin['SYM_One Row Coded Symptoms'][i].split(',')

# %%
# missing data: not available, etc. 
origin['CI_Age Unit'] = origin['CI_Age Unit'].replace('Not Available', np.nan)
# Deal with decades
origin.ix[origin['CI_Age Unit'] == 'Decade(s)', 'CI_Age at Adverse Event'] *= 10
origin.ix[origin['CI_Age Unit'] == 'Decade(s)', 'CI_Age Unit'] = 'Year(s)'

origin['CI_Age Unit'].value_counts()


# for i in range(50):
#     if origin['CI_Age Unit'][i] == "Not Available":
#         origin['CI_Age Unit'][i] = np.nan
        
#origin.ix[['Not Available'],['CI_Age Unit']] = np.nan
# Out:
# Year(s)     46990
# Month(s)     1153
# Week(s)       162
# Day(s)        138
# Name: CI_Age Unit, dtype: int64

# %%
# remove outliers, and do descriptive analysis for each category of CI_Age Unit
# days
#origin[origin['CI_Age Unit'] == 'Day(s)'].describe()

for i in range(len(origin.index)):
    if (origin['CI_Age at Adverse Event'][i] >= 31) & (origin['CI_Age Unit'][i] == 'Day(s)'):
        origin['CI_Age at Adverse Event'][i] /= 30
        origin['CI_Age Unit'][i] = 'Month(s)'
        
days = origin[origin['CI_Age Unit'] == 'Day(s)']
#days
days['CI_Age at Adverse Event'].describe()
# Out:
# /Users/huilin/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/huilin/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# count    86.000000
# mean     10.465116
# std       9.223624
# min       0.000000
# 25%       2.250000
# 50%       7.500000
# 75%      18.750000
# max      30.000000
# Name: CI_Age at Adverse Event, dtype: float64

# %%
origin['CI_Age Unit'].value_counts()
# Out:
# Year(s)     46990
# Month(s)     1205
# Week(s)       162
# Day(s)         86
# Name: CI_Age Unit, dtype: int64

# %%
# weeks
weeks = origin[origin['CI_Age Unit'] == 'Week(s)']
weeks['CI_Age at Adverse Event'].describe()

for i in range(len(origin.index)):
    if (origin['CI_Age at Adverse Event'][i] > 4) & (origin['CI_Age Unit'][i] == 'Week(s)'):
        origin['CI_Age at Adverse Event'][i] /= 4
        origin['CI_Age Unit'][i] = 'Month(s)'
    if (origin['CI_Age at Adverse Event'][i] <= 4) & (origin['CI_Age Unit'][i] == 'Week(s)'):
        origin['CI_Age at Adverse Event'][i] *= 7
        origin['CI_Age Unit'][i] = 'Day(s)'
        
weeks = origin[origin['CI_Age Unit'] == 'Week(s)']
weeks
weeks['CI_Age at Adverse Event'].describe()
# Out:
# /Users/huilin/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/huilin/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/huilin/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/huilin/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: CI_Age at Adverse Event, dtype: float64

# %%
# remove outliers, and do descriptive analysis for each category of CI_Age Unit
# month

for i in range(len(origin.index)):
    if (origin['CI_Age at Adverse Event'][i] > 12) & (origin['CI_Age Unit'][i] == 'Month(s)'):
        origin['CI_Age at Adverse Event'][i] /= 12
        origin['CI_Age Unit'][i] = 'Year(s)'
        
month = origin[origin['CI_Age Unit'] == 'Month(s)']
month
month['CI_Age at Adverse Event'].describe()

#origin[(origin['CI_Age at Adverse Event'] >= 36) & (origin['CI_Age Unit'] == 'Month(s)')] = np.nan
#months = origin[origin['CI_Age Unit'] == 'Month(s)']
#months['CI_Age at Adverse Event'].describe()
# Out:
# /Users/huilin/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/huilin/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# count    998.000000
# mean       5.237792
# std        3.074188
# min        0.000000
# 25%        2.500000
# 50%        5.000000
# 75%        8.000000
# max       12.000000
# Name: CI_Age at Adverse Event, dtype: float64

# %%
# remove outliers, and do descriptive analysis for each category of CI_Age Unit
# years: years >= 100 can be viewed as outliers
origin[(origin['CI_Age at Adverse Event']>= 100) & (origin['CI_Age Unit'] == 'Year(s)')] = np.nan
years = origin[origin['CI_Age Unit'] == 'Year(s)']
years['CI_Age at Adverse Event'].describe()
# Out:
# count    47309.000000
# mean        51.514467
# std         22.257302
# min          1.000000
# 25%         36.000000
# 50%         54.000000
# 75%         69.000000
# max         99.000000
# Name: CI_Age at Adverse Event, dtype: float64

# %%
origin['CI_Age Unit'].value_counts()
# Out:
# Year(s)     47309
# Month(s)      998
# Day(s)        116
# Name: CI_Age Unit, dtype: int64

# %%
# after 
46990 + 1153 + 162 + 138
# Out:
# 48443

# %%
# after: the difference is outliers 
47309 + 998 + 116
# Out:
# 48423

# %%
# create an age_interval based on age variable

origin['Age_interval'] = np.nan

yearsbin = [0, 20, 40, 60, 80, 100]
yearscategory = ['0-20', '21-40', '41-60','61-80','81-100']
year_interval = pd.cut(origin['CI_Age at Adverse Event'][origin['CI_Age Unit'] == 'Year(s)'], yearsbin, labels=yearscategory)

origin['Age_interval'][origin['CI_Age Unit'] == 'Year(s)'] = year_interval

#year_interval
#df.loc[df['B'] == 3, 'A'].
#origin.loc[origin['CI_Age Unit'] == 'Month(s)', 'Age_interval']
# Out:
# /Users/huilin/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# age_interval: month
monthsbin = [0, 3, 6, 9, 12]
monthscategory = ['0-3', '3-6', '6-9','9-12']
month_interval = pd.cut(origin['CI_Age at Adverse Event'][origin['CI_Age Unit'] == 'Month(s)'], monthsbin, labels=monthscategory)

origin['Age_interval'][origin['CI_Age Unit'] == 'Month(s)'] = month_interval
# Out:
# /Users/huilin/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# age_interval: days
daysbin = [0, 5, 10, 15, 20, 25, 30]
dayscategory = ['0-5', '5-10', '10-15','15-20', '20-25', '25-30']
days_interval = pd.cut(origin['CI_Age at Adverse Event'][origin['CI_Age Unit'] == 'Day(s)'], daysbin, labels=dayscategory)

origin['Age_interval'][origin['CI_Age Unit'] == 'Day(s)'] = days_interval
# Out:
# /Users/huilin/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
#origin['Age_interval'].describe()

# %%
# Gender: missing data 
origin['CI_Gender'].value_counts()
origin['CI_Gender'] = origin['CI_Gender'].replace('Not Available', np.nan)
origin['CI_Gender'] = origin['CI_Gender'].replace('Unknown', np.nan)
origin['CI_Gender'] = origin['CI_Gender'].replace('Not Reported', np.nan)
origin['CI_Gender'].value_counts()
# Out:
# Female    50383
# Male      25374
# Name: CI_Gender, dtype: int64

# %%
# Rename variables
origin = origin.rename(columns={'AEC_Event Start Date': 'Start_Date', 'PRI_Product Role': 'Role', 
                                'PRI_Reported Brand/Product Name': 'Brand/Product', 'PRI_FDA Industry Name': 'Industry'})                            
origin = origin.rename(columns={'CI_Age at Adverse Event': 'Age', 'CI_Age Unit': 'Age', 'CI_Age Unit': 'Age Unit', 
                                'CI_Gender': 'Gender'})

# %%
#origin['PRI_FDA Industry Name'] = origin['PRI_FDA Industry Name'].apply(lambda x: x.split('/')[0])

# %%
#origin['PRI_FDA Industry Name']

# %%
#origin['PRI_FDA Industry Name'][(origin['CI_Gender'] == 'Female') & (origin['CI_Age Unit'] == 'Year(s)')].value_counts()

# %%
len(origin.index)
# Out:
# 80169

# %%
clean_data = origin
clean_data.to_csv('clean_data.txt')

# %%
print origin.dtypes
# Out:
# RA_Report #                    object
# RA_CAERS Created Date          object
# Start_Date                     object
# Role                           object
# Brand/Product                  object
# PRI_FDA Industry Code          object
# Industry                       object
# Age                           float64
# Age Unit                       object
# Gender                         object
# AEC_One Row Outcomes           object
# SYM_One Row Coded Symptoms     object
# Age_interval                   object
# dtype: object

# %%
origin['Age_interval'] = origin['Age_interval'].astype('str')

# %%
origin['Age_interval'][origin['Age Unit'] == 'Month(s)'].value_counts()
# Out:
# 0-3     371
# 3-6     282
# 6-9     233
# 9-12    111
# Name: Age_interval, dtype: int64
